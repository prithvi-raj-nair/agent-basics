# %% [markdown]
# ## Basic Multi-LLM Workflows
#
# This notebook demonstrates three simple multi-LLM workflows. They trade off cost or latency for potentially improved task performances:
#
# 1. **Prompt-Chaining**: Decomposes a task into sequential subtasks, where each step builds on previous results
# 2. **Parallelization**: Distributes independent subtasks across multiple LLMs for concurrent processing
# 3. **Routing**: Dynamically selects specialized LLM paths based on input characteristics
#
# Note: These are sample implementations meant to demonstrate core concepts - not production code.

# %%
from concurrent.futures import ThreadPoolExecutor
from typing import List, Dict
from util import llm_call, extract_xml

# %%
def chain(input: str, prompts: List[str]) -> str:
    """Chain multiple LLM calls sequentially, passing results between steps."""
    result = input
    for i, prompt in enumerate(prompts, 1):
        print(f"\nStep {i}:")
        result = llm_call(f"{prompt}\nInput: {result}")
        print(result)
    return result


def parallel(prompt: str, inputs: List[str], n_workers: int = 3) -> List[str]:
    """Process multiple inputs concurrently with the same prompt."""
    with ThreadPoolExecutor(max_workers=n_workers) as executor:
        futures = [executor.submit(llm_call, f"{prompt}\nInput: {x}") for x in inputs]
        return [f.result() for f in futures]


def route(input: str, routes: Dict[str, str]) -> str:
    """Route input to specialized prompt using content classification."""
    # First determine appropriate route using LLM with chain-of-thought
    print(f"\nAvailable routes: {list(routes.keys())}")
    selector_prompt = f"""
    Analyze the input and select the most appropriate support team from these options: {list(routes.keys())}
    First explain your reasoning, then provide your selection in this XML format:

    <reasoning>
    Brief explanation of why this ticket should be routed to a specific team.
    Consider key terms, user intent, and urgency level.
    </reasoning>

    <selection>
    The chosen team name
    </selection>

    Input: {input}""".strip()

    route_response = llm_call(selector_prompt)
    reasoning = extract_xml(route_response, "reasoning")
    route_key = extract_xml(route_response, "selection").strip().lower()

    print("Routing Analysis:")
    print(reasoning)
    print(f"\nSelected route: {route_key}")

    # Process input with selected specialized prompt
    selected_prompt = routes[route_key]
    return llm_call(f"{selected_prompt}\nInput: {input}")

# %% [markdown]
# ## Example Usage
#
# Below are practical examples demonstrating each workflow:
# 1. Chain workflow for structured data extraction and formatting
# 2. Parallelization workflow for stakeholder impact analysis
# 3. Route workflow for customer support ticket handling

# %%
# Example 1: Chain workflow for structured data extraction and formatting
# Each step progressively transforms raw text into a formatted table

data_processing_steps = [
    """Extract only the numerical values and their associated metrics from the text.
    Format each as 'value: metric' on a new line.
    Example format:
    92: customer satisfaction
    45%: revenue growth""",
    """Convert all numerical values to percentages where possible.
    If not a percentage or points, convert to decimal (e.g., 92 points -> 92%).
    Keep one number per line.
    Example format:
    92%: customer satisfaction
    45%: revenue growth""",
    """Sort all lines in descending order by numerical value.
    Keep the format 'value: metric' on each line.
    Example:
    92%: customer satisfaction
    87%: employee satisfaction""",
    """Format the sorted data as a markdown table with columns:
    | Metric | Value |
    |:--|--:|
    | Customer Satisfaction | 92% |""",
]

report = """
Q3 Performance Summary:
Our customer satisfaction score rose to 92 points this quarter.
Revenue grew by 45% compared to last year.
Market share is now at 23% in our primary market.
Customer churn decreased to 5% from 8%.
New user acquisition cost is $43 per user.
Product adoption rate increased to 78%.
Employee satisfaction is at 87 points.
Operating margin improved to 34%.
"""

print("\nInput text:")
print(report)
formatted_result = chain(report, data_processing_steps)
# Out:
# Input text:
#
# Q3 Performance Summary:
# Our customer satisfaction score rose to 92 points this quarter.
# Revenue grew by 45% compared to last year.
# Market share is now at 23% in our primary market.
# Customer churn decreased to 5% from 8%.
# New user acquisition cost is $43 per user.
# Product adoption rate increased to 78%.
# Employee satisfaction is at 87 points.
# Operating margin improved to 34%.
#
#
# Step 1:
# 92: customer satisfaction score
# 45%: revenue growth
# 23%: market share
# 5%: customer churn
# 8%: customer churn (previous)
# $43: user acquisition cost
# 78%: product adoption rate
# 87: employee satisfaction
# 34%: operating margin
#
# Step 2:
# 92%: customer satisfaction score
# 45%: revenue growth
# 23%: market share
# 5%: customer churn
# 8%: customer churn (previous)
# $43: user acquisition cost
# 78%: product adoption rate
# 87%: employee satisfaction
# 34%: operating margin
#
# Step 3:
# 92%: customer satisfaction score
# 87%: employee satisfaction
# 78%: product adoption rate
# 45%: revenue growth
# $43: user acquisition cost
# 34%: operating margin
# 23%: market share
# 8%: customer churn (previous)
# 5%: customer churn
#
# Step 4:
# | Metric | Value |
# |:--|--:|
# | Customer Satisfaction | 92% |
# | Employee Satisfaction | 87% |
# | Product Adoption Rate | 78% |
# | Revenue Growth | 45% |
# | User Acquisition Cost | $43 |
# | Operating Margin | 34% |
# | Market Share | 23% |
# | Customer Churn (Previous) | 8% |
# | Customer Churn | 5% |

# %%
# Example 2: Parallelization workflow for stakeholder impact analysis
# Process impact analysis for multiple stakeholder groups concurrently

stakeholders = [
    """Customers:
    - Price sensitive
    - Want better tech
    - Environmental concerns""",
    """Employees:
    - Job security worries
    - Need new skills
    - Want clear direction""",
    """Investors:
    - Expect growth
    - Want cost control
    - Risk concerns""",
    """Suppliers:
    - Capacity constraints
    - Price pressures
    - Tech transitions""",
]

impact_results = parallel(
    """Analyze how market changes will impact this stakeholder group.
    Provide specific impacts and recommended actions.
    Format with clear sections and priorities.""",
    stakeholders,
)

for result in impact_results:
    print(result)
    print("+" * 80)
# Out:
# # Stakeholder Impact Analysis: Customers
#
# ## Executive Summary
# Price-sensitive customers seeking better technology with environmental concerns face a complex market landscape requiring strategic navigation of competing priorities.
#
# ---
#
# ## Key Market Changes & Direct Impacts
#
# ### 1. **Technology Evolution**
# **Impacts:**
# - ✓ **Positive**: Access to improved features, performance, and user experience
# - ✗ **Negative**: Faster product obsolescence; pressure to upgrade frequently
# - ✗ **Negative**: Learning curve for new technologies increases
#
# ### 2. **Pricing Pressures**
# **Impacts:**
# - ✗ **Critical**: Rising costs due to supply chain disruptions and inflation
# - ✗ **Critical**: Premium pricing for sustainable/eco-friendly options
# - ✓ **Positive**: Increased competition may drive some price reductions
# - ⚠ **Mixed**: Subscription models replace one-time purchases (ongoing costs vs. lower entry point)
#
# ### 3. **Sustainability Shift**
# **Impacts:**
# - ✓ **Positive**: More eco-friendly product options available
# - ✗ **Negative**: "Green premium" increases upfront costs
# - ✓ **Positive**: Long-term savings through energy efficiency
# - ⚠ **Mixed**: Greenwashing makes authentic choices difficult to identify
#
# ---
#
# ## Priority Recommendations
#
# ### **HIGH PRIORITY** 🔴
#
# 1. **Adopt Value-Based Purchasing Strategy**
#    - Focus on total cost of ownership (TCO) rather than upfront price
#    - Calculate long-term savings from energy-efficient products
#    - Prioritize durability and repairability over cheapest option
#    - **Action**: Create a personal TCO calculator for major purchases
#
# 2. **Leverage Certified Sustainability Standards**
#    - Look for verified certifications (Energy Star, B-Corp, Cradle to Cradle)
#    - Avoid vague environmental claims without third-party validation
#    - **Action**: Bookmark trusted certification databases before shopping
#
# 3. **Demand Transparency from Vendors**
#    - Request detailed environmental impact data
#    - Ask about repair options and product lifespan
#    - Inquire about trade-in or recycling programs
#    - **Action**: Use purchasing power to reward transparent companies
#
# ### **MEDIUM PRIORITY** 🟡
#
# 4. **Explore Alternative Ownership Models**
#    - Consider refurbished/certified pre-owned technology
#    - Evaluate product-as-a-service or leasing options
#    - Join sharing economy platforms where appropriate
#    - **Action**: Compare 3 purchasing models before major tech investments
#
# 5. **Build Technology Literacy**
#    - Invest time in understanding which features provide real value
#    - Avoid paying premium for unnecessary specifications
#    - Learn basic maintenance to extend product life
#    - **Action**: Allocate 2 hours monthly to tech education
#
# 6. **Join Consumer Advocacy Groups**
#    - Participate in collective bargaining for better prices
#    - Support right-to-repair legislation
#    - Share experiences to hold companies accountable
#    - **Action**: Join 1-2 relevant consumer organizations
#
# ### **LOW PRIORITY** 🟢
#
# 7. **Monitor Market Timing**
#    - Track seasonal sales cycles for better pricing
#    - Wait for technology maturity before early adoption
#    - **Action**: Set price alerts for desired products
#
# 8. **Optimize Existing Technology**
#    - Maximize current product lifespan through proper care
#    - Upgrade software before hardware when possible
#    - **Action**: Schedule quarterly device maintenance reviews
#
# ---
#
# ## Risk Mitigation Strategies
#
# | Risk | Mitigation |
# |------|------------|
# | **Affordability Crisis** | Build emergency tech fund; prioritize essential vs. nice-to-have features |
# | **Greenwashing Deception** | Rely only on third-party certifications; research company track records |
# | **Technology Lock-in** | Choose products with open standards; avoid proprietary ecosystems |
# | **Rapid Obsolescence** | Buy slightly behind cutting edge; ensure software support duration |
#
# ---
#
# ## Opportunities to Monitor
#
# 1. **Circular Economy Growth**: Expanding refurbishment and resale markets
# 2. **Regulatory Changes**: Right-to-repair laws improving product longevity
# 3. **Green Financing**: Emerging low-interest loans for sustainable purchases
# 4. **Technology Democratization**: Open-source alternatives reducing costs
#
# ---
#
# ## Success Metrics
#
# Track these indicators quarterly:
# - **Cost per year of use** (purchase price ÷ product lifespan)
# - **Energy cost savings** from efficient products
# - **Percentage of purchases** meeting environmental standards
# - **Product lifespan** compared to category averages
#
# ---
#
# ## Conclusion
#
# The intersection of price sensitivity, technology demands, and environmental concerns creates both challenges and opportunities. Success requires shifting from lowest-price to best-value thinking, becoming an informed advocate, and supporting market forces that align quality, sustainability, and affordability.
#
# **Next Step**: Prioritize the HIGH PRIORITY actions and implement within 30 days.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# # Stakeholder Impact Analysis: Employees
#
# ## Executive Summary
# Market changes pose significant challenges to employee stability, skill relevance, and organizational clarity. Immediate action is required to maintain workforce engagement and capability.
#
# ---
#
# ## Current Concerns Assessment
#
# ### 1. Job Security Worries
# **Severity: HIGH**
# - Uncertainty creates productivity loss and talent drain
# - Competitors may poach anxious top performers
# - Morale impacts team collaboration and innovation
#
# ### 2. Need for New Skills
# **Severity: HIGH**
# - Existing skill gaps threaten competitive positioning
# - Technology/market evolution outpacing current capabilities
# - Risk of workforce obsolescence
#
# ### 3. Want Clear Direction
# **Severity: MEDIUM-HIGH**
# - Leadership communication gaps creating confusion
# - Lack of strategic clarity hampering decision-making
# - Employees unable to align efforts with company goals
#
# ---
#
# ## Specific Market Change Impacts
#
# ### Short-term (0-6 months)
# - **Increased anxiety** leading to 15-25% higher voluntary turnover risk
# - **Productivity decline** of 10-20% due to distraction and uncertainty
# - **Recruitment challenges** as employer brand weakens
#
# ### Medium-term (6-18 months)
# - **Skills obsolescence** making 30-40% of current roles less relevant
# - **Competitive disadvantage** as other firms upskill faster
# - **Innovation stagnation** from risk-averse, worried workforce
#
# ### Long-term (18+ months)
# - **Talent exodus** of high performers seeking stability elsewhere
# - **Cultural erosion** and loss of institutional knowledge
# - **Market position decline** due to capability gaps
#
# ---
#
# ## Recommended Actions
#
# ### PRIORITY 1: Address Job Security (Immediate)
#
# **Action 1.1: Transparent Communication Campaign**
# - Weekly leadership updates on company position and strategy
# - Town halls with Q&A sessions (bi-weekly minimum)
# - Clear messaging: what's changing, what's stable, timeline
# - **Owner:** CEO/CHRO | **Timeline:** Start within 1 week
#
# **Action 1.2: Job Security Framework**
# - Define which roles are secure, evolving, or at risk
# - Create transition plans for affected positions
# - Offer redeployment options before external hiring
# - **Owner:** HR Leadership | **Timeline:** 2-4 weeks
#
# **Action 1.3: Retention Incentives**
# - Stay bonuses for critical talent (top 20%)
# - Performance-based security guarantees
# - Enhanced benefits during transition period
# - **Owner:** Compensation Team | **Timeline:** 3-6 weeks
#
# ---
#
# ### PRIORITY 2: Skill Development (Urgent)
#
# **Action 2.1: Skills Gap Analysis**
# - Assess current vs. required future capabilities
# - Identify critical skill shortages by department
# - Map individual development needs
# - **Owner:** L&D + Department Heads | **Timeline:** 4 weeks
#
# **Action 2.2: Rapid Upskilling Program**
# - Launch 90-day intensive training for priority skills
# - Partner with online platforms (Coursera, LinkedIn Learning)
# - Allocate 4-6 hours/week for learning during work time
# - Certifications with completion bonuses
# - **Owner:** Learning & Development | **Timeline:** 6-8 weeks to launch
#
# **Action 2.3: Internal Mobility Program**
# - Create pathways to transition into growing roles
# - Mentorship pairing with skilled employees
# - Cross-functional project assignments
# - **Owner:** HR + Business Unit Leaders | **Timeline:** 8-12 weeks
#
# **Action 2.4: External Talent Infusion**
# - Hire specialists to teach and lead new capabilities
# - Create "learning pods" mixing new and existing staff
# - Knowledge transfer requirements for new hires
# - **Owner:** Talent Acquisition | **Timeline:** Ongoing
#
# ---
#
# ### PRIORITY 3: Provide Clear Direction (High)
#
# **Action 3.1: Strategic Clarity Cascade**
# - Publish clear 3-year strategic roadmap
# - Department-level strategy translation workshops
# - Individual goal alignment sessions
# - Quarterly strategy refresh communications
# - **Owner:** Executive Team | **Timeline:** 2 weeks
#
# **Action 3.2: Decision-Making Framework**
# - Establish clear priorities and trade-off criteria
# - Empower managers with decision authority
# - Create escalation paths for ambiguous situations
# - **Owner:** COO + Department Heads | **Timeline:** 4 weeks
#
# **Action 3.3: Regular Feedback Loops**
# - Monthly pulse surveys on clarity and confidence
# - Skip-level meetings for direct employee input
# - Anonymous feedback channels
# - Visible action on employee concerns
# - **Owner:** HR + All Managers | **Timeline:** Ongoing, start in 2 weeks
#
# ---
#
# ## Success Metrics
#
# ### Leading Indicators (Track Monthly)
# - Employee engagement scores (target: >70%)
# - Training completion rates (target: >85%)
# - Internal communication effectiveness ratings (target: >75%)
# - Voluntary turnover rate (target: <10% annually)
#
# ### Lagging Indicators (Track Quarterly)
# - Skills assessment improvement scores
# - Productivity metrics by department
# - Time-to-competency for new skills
# - Employee Net Promoter Score (eNPS)
#
# ---
#
# ## Resource Requirements
#
# ### Budget Allocation
# - **Training & Development:** $500-1,000 per employee
# - **Retention Incentives:** 5-10% of at-risk payroll
# - **Communication Tools:** $50,000-100,000
# - **External Expertise:** $200,000-500,000
#
# ### Time Investment
# - **Leadership:** 5-8 hours/week on communication
# - **Managers:** 3-5 hours/week on coaching
# - **Employees:** 4-6 hours/week on learning
#
# ---
#
# ## Risk Mitigation
#
# **If actions are delayed:**
# - Expect 20-30% turnover in top talent within 6 months
# - Competitive capability gap widening by 12-18 months
# - Recovery timeline extends to 2-3 years
#
# **Quick wins to build momentum:**
# 1. CEO video message within 48 hours
# 2. First town hall within 1 week
# 3. Learning platform access within 2 weeks
# 4. Visible retention offers to key talent within 3 weeks
#
# ---
#
# ## Conclusion
#
# Employee concerns represent both significant risk and opportunity. Organizations that act decisively on security, skills, and clarity will emerge with stronger, more capable, and more loyal workforces. **The window for action is 30-60 days before irreversible talent loss occurs.**
#
# **Next Step:** Executive team meeting within 72 hours to assign owners and approve budget.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# # Stakeholder Impact Analysis: Investors
#
# ## Executive Summary
# Investors face a complex landscape balancing growth expectations against cost pressures and heightened risk exposure. Strategic repositioning and transparent communication will be critical to maintaining confidence and returns.
#
# ---
#
# ## Specific Impacts
#
# ### 1. **Growth Expectations**
# **Impact Level: HIGH**
#
# - **Market volatility** may compress revenue growth rates by 15-25%
# - **Sector disruption** could shift growth from traditional to emerging segments
# - **Competitive pressure** may require increased investment to maintain market share
# - **Economic headwinds** could extend payback periods on capital investments
#
# ### 2. **Cost Control Pressures**
# **Impact Level: CRITICAL**
#
# - **Margin compression** from inflation and supply chain costs (3-7% impact)
# - **Operational efficiency demands** requiring technology investments
# - **Talent retention costs** rising 10-20% in competitive markets
# - **Regulatory compliance** adding 5-15% to operational expenses
#
# ### 3. **Risk Exposure**
# **Impact Level: HIGH**
#
# - **Market volatility** increasing portfolio value fluctuations (±20-30%)
# - **Geopolitical uncertainty** affecting international operations
# - **Technology disruption** threatening existing business models
# - **ESG compliance** creating new liability categories
#
# ---
#
# ## Recommended Actions
#
# ### **PRIORITY 1: Immediate (0-3 months)**
#
# #### Enhance Transparency & Communication
# - **Action**: Implement monthly investor briefings with real-time dashboards
# - **Rationale**: Reduces uncertainty and maintains confidence during volatility
# - **Owner**: CFO/Investor Relations
# - **Metrics**: Investor satisfaction scores, inquiry volume reduction
#
# #### Risk Mitigation Framework
# - **Action**: Conduct comprehensive risk audit and stress testing
# - **Rationale**: Quantifies exposure and enables proactive management
# - **Owner**: Risk Management/Board
# - **Metrics**: Risk-adjusted return ratios, scenario analysis results
#
# ### **PRIORITY 2: Short-term (3-6 months)**
#
# #### Portfolio Optimization
# - **Action**: Divest underperforming assets; reallocate to high-growth segments
# - **Rationale**: Improves overall returns while controlling costs
# - **Owner**: Strategy/M&A Team
# - **Metrics**: ROI improvement, portfolio beta, growth rate acceleration
#
# #### Cost Transformation Program
# - **Action**: Launch zero-based budgeting and automation initiatives
# - **Rationale**: Protects margins without sacrificing growth investments
# - **Owner**: Operations/Finance
# - **Metrics**: Cost-to-serve reduction (target: 15-20%), EBITDA margin
#
# #### Strategic Hedging
# - **Action**: Implement financial hedges for currency, commodity, and interest rate exposure
# - **Rationale**: Stabilizes earnings and protects shareholder value
# - **Owner**: Treasury/CFO
# - **Metrics**: Earnings volatility reduction, hedge effectiveness ratio
#
# ### **PRIORITY 3: Medium-term (6-12 months)**
#
# #### Growth Diversification Strategy
# - **Action**: Develop 3-5 new revenue streams in adjacent markets
# - **Rationale**: Reduces dependency on core business; captures emerging opportunities
# - **Owner**: Business Development/Strategy
# - **Metrics**: Revenue diversification index, new market penetration rates
#
# #### ESG Integration
# - **Action**: Embed ESG metrics into investment criteria and reporting
# - **Rationale**: Attracts ESG-focused capital; reduces regulatory risk
# - **Owner**: Sustainability/Board
# - **Metrics**: ESG ratings improvement, access to green financing
#
# #### Technology Modernization
# - **Action**: Accelerate digital transformation and AI adoption
# - **Rationale**: Drives efficiency and competitive advantage
# - **Owner**: CTO/Digital Transformation
# - **Metrics**: Digital revenue percentage, automation rate, tech ROI
#
# ---
#
# ## Key Performance Indicators (KPIs)
#
# | Metric | Current Baseline | 6-Month Target | 12-Month Target |
# |--------|-----------------|----------------|-----------------|
# | Revenue Growth Rate | Baseline | +5-8% | +10-15% |
# | EBITDA Margin | Baseline | +2-3% | +5-7% |
# | Return on Invested Capital | Baseline | +3-5% | +8-12% |
# | Risk-Adjusted Returns | Baseline | +10% | +20% |
# | Investor Confidence Index | Baseline | +15% | +30% |
#
# ---
#
# ## Risk Mitigation Strategies
#
# ### Financial Risks
# - Maintain 18-24 months cash runway
# - Diversify funding sources (debt, equity, alternatives)
# - Implement dynamic capital allocation model
#
# ### Operational Risks
# - Build supply chain redundancy (dual sourcing)
# - Invest in cybersecurity and business continuity
# - Develop talent retention programs
#
# ### Strategic Risks
# - Conduct quarterly market sensing and competitive analysis
# - Establish innovation labs for emerging technologies
# - Create strategic partnerships for market access
#
# ---
#
# ## Communication Plan
#
# ### Monthly
# - Financial performance dashboards
# - Risk exposure updates
# - Market condition analysis
#
# ### Quarterly
# - Comprehensive earnings calls
# - Strategic initiative progress reports
# - Forward guidance adjustments
#
# ### Annually
# - Long-term strategic plan updates
# - Capital allocation framework review
# - Sustainability and ESG reporting
#
# ---
#
# ## Success Factors
#
# ✓ **Transparent Communication**: Build trust through honest, frequent updates
# ✓ **Balanced Approach**: Pursue growth while maintaining fiscal discipline
# ✓ **Proactive Risk Management**: Anticipate and mitigate before issues materialize
# ✓ **Strategic Agility**: Adapt quickly to changing market conditions
# ✓ **Long-term Value Creation**: Balance short-term pressures with sustainable growth
#
# ---
#
# ## Conclusion
#
# Investors will experience significant pressure from market changes, but strategic actions focused on transparency, risk management, and balanced growth can protect and enhance shareholder value. Success requires immediate action on communication and risk mitigation, followed by systematic execution of cost optimization and growth diversification strategies.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# # Stakeholder Impact Analysis: Suppliers
#
# ## Executive Summary
# Suppliers face significant operational and financial pressures from current market changes. Immediate action required on capacity planning and technology adoption to maintain competitiveness and partnership viability.
#
# ---
#
# ## Impact Analysis by Factor
#
# ### 1. Capacity Constraints
# **Severity: HIGH** | **Timeline: Immediate**
#
# #### Specific Impacts:
# - **Revenue Risk**: Unable to fulfill increased order volumes, leading to 15-30% potential revenue loss
# - **Customer Attrition**: Buyers will diversify supplier base, reducing long-term contract stability
# - **Margin Pressure**: Overtime costs and expedited shipping eroding 5-10% margins
# - **Quality Degradation**: Rushed production increasing defect rates by 20-40%
# - **Workforce Strain**: Employee burnout and turnover (up to 25% increase)
#
# #### Root Causes:
# - Labor shortages in skilled positions
# - Equipment utilization at 90%+ capacity
# - Supply chain bottlenecks for raw materials
# - Inadequate production planning systems
#
# ---
#
# ### 2. Price Pressures
# **Severity: HIGH** | **Timeline: Ongoing**
#
# #### Specific Impacts:
# - **Margin Compression**: Input costs rising 8-15% while buyers resist price increases
# - **Cash Flow Strain**: Extended payment terms while facing immediate cost increases
# - **Competitive Disadvantage**: Larger competitors leveraging economies of scale
# - **Contract Losses**: Fixed-price agreements becoming unprofitable
# - **Investment Constraints**: Reduced capital for modernization and expansion
#
# #### Market Dynamics:
# - Raw material inflation (energy, metals, chemicals)
# - Transportation cost volatility
# - Buyer consolidation increasing negotiating power
# - Low-cost international competition
#
# ---
#
# ### 3. Technology Transitions
# **Severity: MEDIUM-HIGH** | **Timeline: 12-36 months**
#
# #### Specific Impacts:
# - **Obsolescence Risk**: Current capabilities becoming non-competitive within 2-3 years
# - **Capital Requirements**: $500K-$5M investment needed for automation/digitalization
# - **Skills Gap**: 40-60% of workforce requiring retraining
# - **Integration Complexity**: 6-18 month implementation disrupting operations
# - **Customer Requirements**: Buyers demanding digital integration (EDI, real-time tracking, quality data)
#
# #### Technology Pressures:
# - Automation and robotics adoption
# - IoT and predictive maintenance
# - Digital supply chain integration
# - Sustainability tracking and reporting
#
# ---
#
# ## Strategic Recommendations
#
# ### PRIORITY 1: Address Capacity Constraints (0-6 months)
#
# #### Immediate Actions:
# 1. **Capacity Audit & Optimization**
#    - Conduct bottleneck analysis across production lines
#    - Implement lean manufacturing principles
#    - Target: 15-20% throughput improvement without capital investment
#
# 2. **Workforce Solutions**
#    - Launch retention program (competitive wages, benefits)
#    - Establish training pipeline with technical schools
#    - Consider temporary staffing for demand spikes
#    - Investment: $200K-500K annually
#
# 3. **Strategic Inventory Management**
#    - Build buffer stock of critical raw materials (3-6 month supply)
#    - Negotiate consignment arrangements with key suppliers
#    - Implement demand forecasting tools
#
# 4. **Customer Communication**
#    - Proactive transparency on lead times
#    - Tiered service levels based on commitment/volume
#    - Collaborative demand planning with top 20% customers
#
# **Expected Outcome**: Stabilize fulfillment rates at 95%+, reduce emergency costs by 30%
#
# ---
#
# ### PRIORITY 2: Manage Price Pressures (0-12 months)
#
# #### Financial Strategies:
# 1. **Cost Structure Optimization**
#    - Conduct zero-based budgeting review
#    - Renegotiate supplier contracts (bulk purchasing, longer terms)
#    - Target: 5-8% cost reduction
#    - Timeline: 3-6 months
#
# 2. **Pricing Strategy Revision**
#    - Implement cost-plus escalation clauses in new contracts
#    - Introduce material surcharges for volatile inputs
#    - Develop value-added service tiers for premium pricing
#    - Quarterly price reviews with customers
#
# 3. **Product Mix Optimization**
#    - Analyze profitability by SKU/customer
#    - Phase out bottom 20% unprofitable products
#    - Focus capacity on high-margin offerings
#    - Expected margin improvement: 3-5%
#
# 4. **Financial Risk Management**
#    - Hedge key commodity exposures (if volume justifies)
#    - Negotiate improved payment terms (net 30 vs. net 60)
#    - Establish credit line for working capital buffer
#
# **Expected Outcome**: Stabilize margins within 2% of historical averages, improve cash conversion cycle by 15 days
#
# ---
#
# ### PRIORITY 3: Navigate Technology Transitions (6-36 months)
#
# #### Phased Implementation:
#
# **Phase 1: Foundation (Months 6-12)**
# - Conduct technology readiness assessment
# - Develop 3-year digital roadmap
# - Implement basic ERP/MRP system if not present
# - Investment: $150K-500K
#
# **Phase 2: Core Capabilities (Months 12-24)**
# - Automate highest-ROI processes (typically packaging, material handling)
# - Deploy IoT sensors for equipment monitoring
# - Integrate digital systems with top 3-5 customers
# - Establish data analytics capabilities
# - Investment: $500K-2M
#
# **Phase 3: Advanced Capabilities (Months 24-36)**
# - Implement predictive maintenance and quality systems
# - Deploy collaborative planning platforms
# - Achieve sustainability tracking/reporting
# - Investment: $300K-1M
#
# #### Workforce Development:
# - Partner with equipment vendors for training
# - Create internal "digital champions" program
# - Hire 2-3 technical specialists
# - Budget: $100K-250K annually
#
# **Expected Outcome**: 20-30% productivity improvement, 15% quality enhancement, position as preferred "modern" supplier
#
# ---
#
# ## Risk Mitigation
#
# ### Critical Risks to Monitor:
#
# | Risk | Probability | Impact | Mitigation |
# |------|-------------|--------|------------|
# | Major customer loss | Medium | High | Diversify customer base, improve service levels |
# | Technology investment failure | Medium | High | Phased approach, proven vendors, pilot programs |
# | Cash flow crisis | Medium | Critical | Maintain credit facility, improve collections |
# | Skilled labor shortage | High | High | Training programs, competitive compensation |
# | Competitor disruption | Medium | Medium | Continuous market intelligence, agility |
#
# ---
#
# ## Success Metrics
#
# ### Key Performance Indicators:
#
# **Operational:**
# - On-time delivery rate: Target 95%+
# - Capacity utilization: Optimal 80-85%
# - First-pass quality yield: Target 98%+
# - Lead time: Reduce by 20%
#
# **Financial:**
# - Gross margin: Maintain within 2% of target
# - Working capital days: Reduce by 15 days
# - Revenue per employee: Increase 15% over 3 years
# - ROI on technology investments: 20%+ over 5 years
#
# **Strategic:**
# - Customer retention rate: 90%+
# - New customer acquisition: 5-10 annually
# - Employee retention: Reduce turnover to <15%
# - Technology adoption score: Industry benchmark by Year 3
#
# ---
#
# ## Conclusion
#
# Suppliers face a challenging environment requiring simultaneous action on multiple fronts. The recommended approach prioritizes immediate operational stability while building toward long-term competitiveness through strategic technology adoption. Success requires disciplined execution, adequate investment, and close collaboration with key customers.
#
# **Total Investment Required**: $1.5M-$8M over 3 years (varies by company size)
# **Expected Return**: Margin stabilization, 25-35% productivity improvement, sustained competitive position
#
# **Next Steps**:
# 1. Executive team review and commitment (Week 1)
# 2. Detailed assessment and planning (Weeks 2-4)
# 3. Begin Priority 1 initiatives (Month 2)
# 4. Quarterly progress reviews and adjustments
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
# Example 3: Route workflow for customer support ticket handling
# Route support tickets to appropriate teams based on content analysis

support_routes = {
    "billing": """You are a billing support specialist. Follow these guidelines:
    1. Always start with "Billing Support Response:"
    2. First acknowledge the specific billing issue
    3. Explain any charges or discrepancies clearly
    4. List concrete next steps with timeline
    5. End with payment options if relevant
    
    Keep responses professional but friendly.
    
    Input: """,
    "technical": """You are a technical support engineer. Follow these guidelines:
    1. Always start with "Technical Support Response:"
    2. List exact steps to resolve the issue
    3. Include system requirements if relevant
    4. Provide workarounds for common problems
    5. End with escalation path if needed
    
    Use clear, numbered steps and technical details.
    
    Input: """,
    "account": """You are an account security specialist. Follow these guidelines:
    1. Always start with "Account Support Response:"
    2. Prioritize account security and verification
    3. Provide clear steps for account recovery/changes
    4. Include security tips and warnings
    5. Set clear expectations for resolution time
    
    Maintain a serious, security-focused tone.
    
    Input: """,
    "product": """You are a product specialist. Follow these guidelines:
    1. Always start with "Product Support Response:"
    2. Focus on feature education and best practices
    3. Include specific examples of usage
    4. Link to relevant documentation sections
    5. Suggest related features that might help
    
    Be educational and encouraging in tone.
    
    Input: """,
}

# Test with different support tickets
tickets = [
    """Subject: Can't access my account
    Message: Hi, I've been trying to log in for the past hour but keep getting an 'invalid password' error. 
    I'm sure I'm using the right password. Can you help me regain access? This is urgent as I need to 
    submit a report by end of day.
    - John""",
    """Subject: Unexpected charge on my card
    Message: Hello, I just noticed a charge of $49.99 on my credit card from your company, but I thought
    I was on the $29.99 plan. Can you explain this charge and adjust it if it's a mistake?
    Thanks,
    Sarah""",
    """Subject: How to export data?
    Message: I need to export all my project data to Excel. I've looked through the docs but can't
    figure out how to do a bulk export. Is this possible? If so, could you walk me through the steps?
    Best regards,
    Mike""",
]

print("Processing support tickets...\n")
for i, ticket in enumerate(tickets, 1):
    print(f"\nTicket {i}:")
    print("-" * 40)
    print(ticket)
    print("\nResponse:")
    print("-" * 40)
    response = route(ticket, support_routes)
    print(response)
    print("+" * 80)
# Out:
# Processing support tickets...
#
#
# Ticket 1:
# ----------------------------------------
# Subject: Can't access my account
#     Message: Hi, I've been trying to log in for the past hour but keep getting an 'invalid password' error.
#     I'm sure I'm using the right password. Can you help me regain access? This is urgent as I need to
#     submit a report by end of day.
#     - John
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Routing Analysis:
#
# This ticket involves a login/authentication issue where the user cannot access their account due to an "invalid password" error. Key factors in this analysis:
#
# 1. **Primary Issue**: Account access problem - the user is locked out and cannot log in
# 2. **Nature of Problem**: Authentication/password issue, which falls under account management rather than billing disputes, product feature questions, or technical bugs with the platform itself
# 3. **User Need**: Password reset or account recovery assistance
# 4. **Urgency**: User mentions needing access by end of day for a report submission
#
# While this could potentially involve technical elements, the core issue is account access and credential management, which is typically handled by account support teams who specialize in authentication, password resets, and account recovery procedures.
#
#
# Selected route: account
# Account Support Response:
#
# **Account Access Issue - Security Verification Required**
#
# Dear John,
#
# Thank you for contacting us regarding your account access issue. I understand the urgency of your situation and will guide you through the secure resolution process.
#
# **Immediate Steps to Regain Access:**
#
# 1. **Password Reset (Recommended)**
#    - Navigate to the login page and click "Forgot Password"
#    - Enter your registered email address
#    - Check your inbox (and spam folder) for the reset link within 5 minutes
#    - Create a new strong password following our requirements
#
# 2. **Account Status Verification**
#    - Before proceeding, verify there are no security holds on your account
#    - Check your email for any security notifications we may have sent
#
# 3. **Alternative Issues to Consider**
#    - Caps Lock may be enabled
#    - Browser autofill might be using an outdated password
#    - Try clearing your browser cache and cookies
#
# **Security Warnings:**
#
# ⚠️ **Never share your password** with anyone, including support staff
# ⚠️ Be cautious of phishing attempts - only use official password reset links
# ⚠️ If you suspect unauthorized access, contact us immediately
#
# **Expected Resolution Time:**
# - Password reset: 5-10 minutes
# - If issues persist after reset: 2-4 hours for investigation
#
# **Next Steps if Problem Continues:**
# Reply with confirmation that you've attempted the password reset, and I'll escalate to our security team for immediate review given your deadline.
#
# Best regards,
# Account Security Team
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Ticket 2:
# ----------------------------------------
# Subject: Unexpected charge on my card
#     Message: Hello, I just noticed a charge of $49.99 on my credit card from your company, but I thought
#     I was on the $29.99 plan. Can you explain this charge and adjust it if it's a mistake?
#     Thanks,
#     Sarah
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Routing Analysis:
#
# This ticket clearly involves a financial concern about charges and pricing. Key indicators include:
# - Direct mention of "charge on my credit card"
# - Specific dollar amounts ($49.99 vs $29.99)
# - Request to "explain this charge and adjust it"
# - Discussion of billing plan discrepancy
#
# The customer is questioning a charge they believe is incorrect and is requesting a potential refund or adjustment. This is a straightforward billing inquiry that requires access to payment records, subscription details, and the ability to process refunds or corrections. While there may be a technical reason for the charge (such as an upgrade or add-on), the primary concern is financial and requires billing team expertise to investigate the charge and make any necessary adjustments.
#
#
# Selected route: billing
# Billing Support Response:
#
# Hi Sarah,
#
# Thank you for reaching out about the $49.99 charge on your account. I completely understand your concern, and I'm happy to help clarify this for you.
#
# **About the Charge:**
#
# There are a few common reasons why you might see a $49.99 charge instead of the expected $29.99:
#
# - **Plan upgrade**: Your account may have been upgraded to a higher-tier plan (either manually or automatically if usage exceeded plan limits)
# - **Additional services or add-ons**: There may be extra features or services added to your base $29.99 plan
# - **Annual vs. monthly billing**: If you switched from monthly to annual billing, the rate structure would differ
# - **Billing error**: It's possible this is indeed a mistake on our end
#
# **Next Steps:**
#
# 1. **Within 24 hours**: I'll review your account history to identify exactly what this charge covers
# 2. **Within 48 hours**: You'll receive a detailed breakdown of the charge via email
# 3. **If it's an error**: We'll process a refund of the $20 difference within 3-5 business days
# 4. **If it's valid**: I'll explain the charges and discuss options to adjust your plan going forward if needed
#
# **Payment Options (if balance remains):**
#
# If any additional charges are valid, you can:
# - Keep the current payment method on file
# - Update your payment method in your account settings
# - Set up a payment plan if needed
#
# Could you confirm your account email or account number so I can investigate this right away?
#
# Best regards,
# Billing Support Team
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Ticket 3:
# ----------------------------------------
# Subject: How to export data?
#     Message: I need to export all my project data to Excel. I've looked through the docs but can't
#     figure out how to do a bulk export. Is this possible? If so, could you walk me through the steps?
#     Best regards,
#     Mike
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Routing Analysis:
#
# This ticket is about understanding how to use a specific feature (data export functionality) within the product. The user is asking:
# 1. Whether bulk export to Excel is possible
# 2. How to perform this action/what steps to follow
#
# Key indicators:
# - "How to" question about product functionality
# - User has already consulted documentation
# - Needs guidance on using a feature
# - No mention of technical errors, bugs, or system issues
# - No billing or payment concerns
# - No account access problems
#
# This is a product usage question that requires knowledge of product features and capabilities. The product team would be best equipped to explain feature availability and provide step-by-step guidance on using export functionality.
#
#
# Selected route: product
# Product Support Response:
#
# Hi Mike,
#
# Great question! I'm happy to walk you through our data export capabilities.
#
# **How to Export Your Project Data:**
#
# 1. **Single Project Export:**
#    - Navigate to your project dashboard
#    - Click the "Actions" menu (three dots in the upper right)
#    - Select "Export to Excel"
#    - Choose your preferred format (XLSX or CSV)
#
# 2. **Bulk Export (Multiple Projects):**
#    - Go to the Projects overview page
#    - Use checkboxes to select the projects you want to export
#    - Click the "Bulk Actions" button at the top
#    - Select "Export Selected" → "Excel Format"
#    - Your download will begin automatically
#
# **Pro Tips:**
# - You can customize which fields to include by clicking "Export Options" before downloading
# - Scheduled exports can be set up under Settings → Automation if you need regular exports
# - For datasets over 10,000 rows, we recommend using CSV format for faster processing
#
# **Related Features You Might Find Helpful:**
# - **Export Templates**: Save your export configurations for repeated use (Settings → Export Templates)
# - **API Access**: For automated exports, our REST API offers programmatic data access
# - **Data Sync**: Connect directly to Google Sheets or Excel Online for real-time updates
#
# **Documentation:**
# - [Complete Export Guide](docs/export-data)
# - [Bulk Operations Tutorial](docs/bulk-actions)
# - [API Export Examples](docs/api/exports)
#
# Let me know if you need any clarification on these steps or run into any issues!
#
# Best regards,
# Product Support Team
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
